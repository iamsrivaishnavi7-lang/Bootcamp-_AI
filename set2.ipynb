# %%
#merge 2 dictionaries
d1={'a':34,'b':57,'c':90}
d2={'b':65,'c':58,'d':87}
for key in d2:
    if key in d1:
        d1[key]=d1[key]+d2[key]
    else:
        d1[key] = d2[key]
        print(d1)
# Out:
# {'a': 34, 'b': 122, 'c': 148, 'd': 87}

# %%
#find key with maximum values
